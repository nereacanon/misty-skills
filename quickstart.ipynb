# %% [markdown]
# # Getting started with Mistral AI API

# %%
! pip install mistralai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 11.1 MB/s eta 0:00:00
# ...

# %%
import base64
import requests
import os
from mistralai import Mistral
import time

def encode_image(image_path):
    """Encode the image to base64."""
    try:
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')
    except FileNotFoundError:
        print(f"Error: The file {image_path} was not found.")
        return None
    except Exception as e:  # Added general exception handling
        print(f"Error: {e}")
        return None

# Api key
api_key = "lIjgsJVC6KFURg49hqYhBj45bkGQz9Kf"

# Specify model
model = "pixtral-12b-2409"

# Initialize the Mistral client
client = Mistral(api_key=api_key)

# %% [markdown]
# ## 1. Probar para un mismo tipo de vino con diferentes imgs cual va mejor

# %% [markdown]
# ![Etiqueta VL20.jpg](data:image/jpeg;base64,...)

# %%
# Path to your image
image_path_1 = "/content/Etiqueta_VL20.jpg"
image_path_2 = "/content/img2.jpg"
image_path_3 = "/content/img3.jpg"

# Getting the base64 string
base64_image_1 = encode_image(image_path_1)
base64_image_2 = encode_image(image_path_2)
base64_image_3 = encode_image(image_path_3)
lista_imgs = [base64_image_1,base64_image_2,base64_image_3]
tiempo = []

# Define the messages for the chat
for base64_image in lista_imgs:
  messages = [
      {
          "role": "user",
          "content": [
              {
                  "type": "text",
                  "text": "Dime el nombre del vino,numero de lote, fecha y bodega?"
              },
              {
                  "type": "image_url",
                  "image_url": f"data:image/jpeg;base64,{base64_image}"
              }
          ]
      }
  ]

  # Get the chat response
  ini = time.time()
  chat_response = client.chat.complete(
      model=model,
      messages=messages
  )
  fin = time.time()
  total = fin - ini
  tiempo.append(total)
  print(total)
  # Print the content of the response
  print(chat_response.choices[0].message.content)
# Out:
# 2.545133590698242
# Claro, aquí está la información solicitada del etiquetado:
#
# - **Nombre del vino:** Valdelobas Valtravieso
# - **Número de lote:** 2020
# - **Fecha:** No se especifica una fecha en el etiquetado proporcionado.
# - **Bodega:** Bodega N° 3.549
#
# Esta información se extrae del texto y los detalles visibles en la etiqueta de la imagen.
# 3.094208240509033
# El nombre del vino es "Valdeobas", el número de lote es "Nº 2874", la fecha es "2020" y la bodega es "Ribera del Duero".
# 3.299442768096924
# El nombre del vino es "Valdelobas", el número de lote es "2020", la fecha es "2020" y la bodega es "Bodegas del Duero".

# %%
import requests
import os
from mistralai import Mistral
import time

def encode_image(image_path):
    """Encode the image to base64."""
    try:
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')
    except FileNotFoundError:
        print(f"Error: The file {image_path} was not found.")
        return None
    except Exception as e:  # Added general exception handling
        print(f"Error: {e}")
        return None

# Path to your image
image_path_1 = "/content/Etiqueta_VL20.jpg"
image_path_2 =
image_path_3 =

# Getting the base64 string
base64_image_1 = encode_image(image_path_1)
base64_image_2 =
base64_image_3 =

lista_imagenes = [base64_image_1,base64_image_2,base64_image_3]

# Specify model
model = "pixtral-12b-2409"

# Initialize the Mistral client
client = Mistral(api_key=api_key)

# Define the messages for the chat
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "Dime el nombre del vino,numero de lote, fecha y bodega?"
            },
            {
                "type": "image_url",
                "image_url": f"data:image/jpeg;base64,{base64_image}"
            }
        ]
    }
]

# Get the chat response
chat_response = client.chat.complete(
    model=model,
    messages=messages
)

# Print the content of the response
print(chat_response.choices[0].message.content)
